# %%
import numpy as np
from kernelcpd import spectral_cpd

# %%
T = 2

# %%
y = np.array([
    [1.5],
    [1.4],
    [1.4],
    [1.4],
    [1.5],
    [3.4],
    [3.5],
    [3.4],
    [3.6],
    [3.6],
])

print(spectral_cpd(y, T))
# Out:
# 4

# %%
y = np.array([
    [1.5,  1.6],
    [1.4,  1.5],
    [1.4,  1.5],
    [1.4,  1.5],
    [1.5,  1.6],
    [3.4,  3.5],
    [3.5,  3.4],
    [3.4,  3.6],
    [3.6,  3.5],
    [3.6,  3.4],
])

print(spectral_cpd(y, T))
# Out:
# 4

# %%
y = np.array([
    [1.5,  3.6],
    [1.4,  3.5],
    [1.4,  3.5],
    [1.4,  3.5],
    [1.5,  3.6],
    [3.4,  1.5],
    [3.5,  1.4],
    [3.4,  1.6],
    [3.6,  1.5],
    [3.6,  1.4],
])

print(spectral_cpd(y, T))
# Out:
# 4
